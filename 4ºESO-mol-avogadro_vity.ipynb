# %% [markdown]
# # MOL, MASA MOLAR Y NÚMERO DE AVOGADRO

# %% [markdown]
# ## Ejercicios adpatados de:
# [link](https://machete2000.files.wordpress.com/2018/10/ejercicios-moles-moleculas-y-masa-molar.pdf)

# %% [markdown]
# **Ejercicio 1º.** Relllena el siguiente cuadro:
#
# | Compuesto | Nº de moles | Masa molecular | Nº de moleculas | Nº de átomos|
# |---|---|---|---|---|
# |$CO_2$   |   |   |   |   |
# |$HNO_3$   |   |   |   |   |
# |$H_2S=_4$   |   |   |   |$ 21.07 \cdot 10^24$  |
# |K   |   |   | $5 \cdot 10^6$  |   |

# %% [markdown]
# **Ejercicio 2º.** Calcular:
#
# a) cuántos átomos de fósforo hay en 0’25 moles de óxido de fósforo (V)
#
# b) la masa en gramos de $2 \cdot 10^24 átomos de Zn (masa atómica del Zn = 65’37 g/mol).

# %% [markdown]
# **Ejercicio 3º.** En 0’6 moles de clorobenceno ( $C_6H_5Cl$)
#
# a) cuántos moles de átomos de C hay
#
# b) Cuantas moléculas
#
# c) Cuantos átomos de H

# %% [markdown]
# **Ejercicio 4º.** Una disolución de HCl concentrado de densidad 1’19 g/cm^3 contiene 37 % de HCl.
#
# Calcular:
#
# a) su fracción molar
#
# b) su molaridad
#
# El volumen que tendría que coger de esta disolución para obtener 1 litro de otra más diluida de concentración 2 M, tras disolverla en agua

# %% [markdown]
# **Ejercicio 5º.** Introducimos O2 en un pistón a 0 ºC de Temperatura, e inicialmente ocupa un volumen de 1 litro, ejerciendo una presión de 2 atmósferas sobre las paredes del pistón.
#
# Si comprimimos el gas hasta un volumen de 0.5 l a la misma temperatura,
#
# Hallar :
#
# a) La presión del gas.
#
# b) La masa del gas encerrado.
#
# Datos : R. 0’082 atm·l/(K·mol)

# %% [markdown]
# **Ejercicio 6º.** Una cierta cantidad de gas, que ocupa un volumen de 1 litro a la temperatura de 100 ºC y 2 atmósferas de presión, se calienta hasta 150 ºC, manteniendo constante la presión. ¿Qué volumen ocupará en estas últimas condiciones ?

# %% [markdown]
# **Ejercicio 7º.** Tenemos un gas encerrado en un recipiente de 6 litros de volumen a una presión de 2 atmósferas y una temperatura de 100 ºC. Calcular la presión que tendría la misma cantidad de gas encerrada en un volumen de 3 litros y a una temperatura de 200 ºC.

# %% [markdown]
# **Ejercicio 8º.** ¿ Cuál es la molaridad de una disolución de ácido sulfúrico del 26 % de riqueza y de densidad 1,19 g/ml?.

# %% [markdown]
# **Ejercicio 9º.** Se mezclan 100 ml de HCl 0,2 M, 400 ml de HCl 0,1 M y 250 ml de agua destilada.
#
# Calcule la molaridad de la disolución resultante ( suponer que los volúmenes son aditivos)

# %% [markdown]
# **Ejercicio 10º.** Ordenar razonadamente, de mayor a menor número de átomos, las cantidades siguientes:
#
# a) 10 g de cloruro de plata.
#
# b) 3·1020 moléculas de dióxido de azufre
#
# c) 4 moles de monóxido de carbono
#
# d) 20 l de oxígeno en condiciones normales.
#
# Datos: Masas atómicas: Cl = 35,5; Ag = 108

# %% [markdown]
# **Ejercicio 11º.** En un recipiente de volumen desconocido se introducen 3·1025 moléculas de hidrógeno gaseoso a una presión de 1’5 atmósferas y a una temperatura de -20 ºC.
#
# Calcular el volumen del recipiente.
#
# Tenemos otro recipiente que tiene $8.5 \cdot 10^24$ moléculas de hidrógeno gaseoso a una temperatura de 40 ºC y a una presión de 500 mm Hg. Calcular el volumen del recipiente.
#
# Si juntamos los dos recipientes, calcular el número de moléculas que hay, el número de moles totales y si la temperatura final es de 5 ºC, calcular la presión del recipiente.
#
# DATO: $R= 0,082 \cdot atm \cdot l \cdot mol^{-1} \cdot k^{⁻1}$

# %% [markdown]
# **Ejercicio 12º.** Tenemos un gas encerrado en un recipiente de 50 litros a una presión de 3
# atmósferas y una temperatura de 340 ºC.
#
# a) Calcular el número de moles que hay de ese gas.
#
# b) Si se comprime hasta los 30 litros a temperatura constante, calcula la presión del
# gas.
#
# c) Si se aumenta la presión hasta los 5000 mm Hg a temperatura constante, calcula
# el volumen del gas.
#
# d) Si se aumenta la presión hasta 10 atmósferas a volumen constante, calcula la
# temperatura del gas.
#
# e) Si disminuye el volumen hasta los 400 cm3 y la presión se pasa a 40 atmósferas,
#
# calcular la temperatura del gas.
#
# DATO: $R= 0.082 \; atm \cdot l \cdot mol^{-1} \cdot k^{-1}$

# %% [markdown]
# **Ejercicio 13º.** Transforma a las unidades indicadas y poner el resultado en notación científica.
#
# a) 100 kg a dg
#
# b) 500 m a km
#
# c) $300 \; \frac{Kg}{m^2} \; a \; \frac{kg}{cm^2}$
#
# d) 800 horas a minutos
#
# e) $20 \; \frac{km}{h} \; a \; \frac{m}{s}$
#
# f) $200 \; \frac{kg}{l} a \frac{hg}{km^3}$
#
# g) $ 300 \; cm^3 \; a \; mm^3$
#
# h) $2 \; 10^4 \; m^2 \; a \; cm²$
#
# i) $3 \cdot 10^{-3} \; mm^3 \; a \; dam^3$
#
# j)
#
# k)
#
# l)
#
# m)
#
# n)
#
# ñ)
#
# o)
#
# p)
#
# q)
#
# r)
#
# s)
#
# t)

# %% [markdown]
# **Ejercicio 14º.** En el interior de un cubo de 3 metros de arista se introduce un líquido de $20 \; \frac{kg}{m^3}$ de densidad. Calcular:
#
# a) Masa del líquido contenido en el cubo.
#
# b) Si con el líquido contenido en el cubo se llena una esfera de 3 metros de diámetro, ¿Cuánto líquido quedará como sobrante en el cubo?.

# %% [markdown]
# **Ejercicio 15º.** Una sustancia tiene una densidad de $3 \; {g}{cn^3} . Calcular:
#
# a) La masa de $20 \; cm^3$ de esa sustancia.
#
# b) El volumen que ocupa 50 gramos de esa sustancia.
#
# c) La masa de $4 \; m^3$ de esa sustancia.
#
# d) El volumen que ocupan 3 kg de esa sustancia

# %% [markdown]
# # Ejercicios de masa molar
#
# Para hallarla se suma la masa de todos los átomos de los elementos que componen la molécula. Hallar la masa molar de las siguientes sustancias

# %% [markdown]
# a) Ácido nítrico
#
# b) Ácido sulfúrico
#
# c) Ácido fosfórico
#
# d) Ácido carbónico
#
# e) Nitrato de hierro(II)
#
# f) Sulfato de oro(I)
#
# g) Dióxido de oro(I)
#
# h) Nitrato de sodio
#
# i) Cloruro de magnesio.
#
# j) Hidróxido de calcio.
#
# k) Carbonato de platino(IV)
#
# l) Yodato de plata.
#
# m) Dihidrogenofosfato de litio

# %% [markdown]
# # Ejercicios de composición centesimal

# %% [markdown]
# Proporción de cada elemento que forma la molécula. Para hallarlo:
#
# 1. Hallar la masa molar.
#
# 2. Hallar la masa de cada elemento en la molécula. Para ello se multiplica la masa atómica del elemento por el número de veces que está presente en la fórmula.
#
# 3. Dividir el valor obtenido en el paso 2 por la masa molar del compuesto, y multiplicar el resultado por cien para obtener un porcentaje.
#
# Calcular la composición centesimal de las especies anteriores.
#
# a) Ácido nítrico
#
# b) Ácido sulfúrico
#
# c) Ácido fosfórico
#
# d) Ácido carbónico
#
# e) Nitrato de hierro(II)
#
# f) Sulfato de oro(I)
#
# g) Dióxido de oro(I)
#
# h) Nitrato de sodio
#
# i) Cloruro de magnesio.
#
# j) Hidróxido de calcio.
#
# k) Carbonato de platino(IV)
#
# l) Yodato de plata.
#
# m) Dihidrogenofosfato de litio.
